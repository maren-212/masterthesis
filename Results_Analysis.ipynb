# %% [markdown]
# #Statistical analysis of the fine-tuning results

# %% [markdown]
# ## Load modules

# %%
from google.colab import drive
import json as js
import pandas as pd
import random
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# %% [markdown]
# ## Set Working directory

# %% [markdown]
# In this work, Google Colab was used and therefore Google Drive was also used to load data. If a different environment is used, the working directory must be adapted.

# %%
drive.mount('/content/drive/')
# %cd /content/drive/My Drive/Colab Notebooks/
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/My Drive/Colab Notebooks

# %% [markdown]
# This code can be customised to set your own WD.

# %%
#path = "/this/is/my/wd"
#set_working_directory(path)

# %% [markdown]
# ## Load results data

# %%
df = pd.read_excel('Results.xlsx', sheet_name='results')
df.columns = df.columns.str.strip()
df
# Out:
#                                Name pretrained_model  Labels  ANLI_Train  \
# 0        model10_deberta_base_colab       deberta_v3       3           1
# 1                   model10_roberta     roberta_base       2           0
# 2                   model11_roberta     roberta_base       2           0
# 3        model12_deberta_base_colab       deberta_v3       2           0
# 4                   model12_roberta     roberta_base       2           0
# 5                   model13_roberta     roberta_base       2           0
# 6        model14_deberta_base_colab       deberta_v3       2           0
# 7                   model14_roberta     roberta_base       3           1
# 8        model15_deberta_base_colab       deberta_v3       3           0
# 9                   model15_roberta     roberta_base       2           0
# 10       model16_deberta_base_colab       deberta_v3       3           0
# 11                  model16_roberta     roberta_base       2           0
# 12       model17_deberta_base_colab       deberta_v3       3           0
# 13                  model17_roberta     roberta_base       2           0
# 14       model18_deberta_base_colab       deberta_v3       3           0
# 15                  model18_roberta     roberta_base       2           1
# 16       model20_deberta_base_colab       deberta_v3       3           1
# 17       model21_deberta_base_colab       deberta_v3       2           0
# 18       model22_deberta_base_colab       deberta_v3       2           1
# 19       model23_deberta_base_colab       deberta_v3       2           1
# 20  model26_bert-base-uncased_colab        bert_base       3           0
# 21  model27_bert-base-uncased_colab        bert_base       3           1
# 22  model28_bert-base-uncased_colab        bert_base       2           0
# 23  model32_bert-base-uncased_colab        bert_base       2           0
# 24  model33_bert-base-uncased_colab        bert_base       2           0
# 25  model34_bert-base-uncased_colab        bert_base       3           0
# 26  model35_bert-base-uncased_colab        bert_base       3           0
# 27  model36_bert-base-uncased_colab        bert_base       3           1
# 28  model38_bert-base-uncased_colab        bert_base       2           1
# 29  model39_bert-base-uncased_colab        bert_base       2           1
# 30                   model4_roberta     roberta_base       3           1
# 31  model40_bert-base-uncased_colab        bert_base       2           0
# 32  model41_bert-base-uncased_colab        bert_base       2           1
# 33                   model5_roberta     roberta_base       3           1
# 34                   model6_roberta     roberta_base       3           1
# 35                   model7_roberta     roberta_base       3           1
# 36                   model8_roberta     roberta_base       3           1
# 37                   model9_roberta     roberta_base       3           2
#
#     MNLI_Train  NLI Fever_Train  VitaminC_Train  SciFact_Train  DocNLI_Train  \
# 0            1                1               0              0             0
# 1            0                0               2              2             0
# 2            0                0               2              2             0
# 3            0                0               0              0             0
# 4            0                0               2              2             0
# 5            0                0               2              2             0
# 6            0                0               2              2             0
# 7            1                1               0              0             0
# 8            0                0               1              0             0
# 9            0                1               0              0             0
# 10           0                0               1              0             0
# 11           0                0               0              0             0
# 12           0                1               0              0             0
# 13           0                0               1              0             0
# 14           0                1               0              0             0
# 15           0                0               1              0             0
# 16           0                0               0              0             0
# 17           0                0               1              1             0
# 18           0                0               1              0             0
# 19           0                0               1              0             0
# 20           0                0               0              0             0
# 21           0                1               1              0             0
# 22           0                0               0              0             0
# 23           0                0               2              2             0
# 24           0                0               2              2             0
# 25           0                0               1              0             0
# 26           0                1               0              0             0
# 27           0                0               0              0             0
# 28           0                0               1              0             0
# 29           1                1               0              0             0
# 30           0                0               0              0             0
# 31           0                0               1              1             0
# 32           0                0               1              0             0
# 33           0                0               0              0             0
# 34           0                0               1              0             0
# 35           0                0               1              0             0
# 36           0                0               1              0             0
# 37           0                0               2              0             0
#
#     SNLI_Train  ...  train_batchsize  warmup_ratio  weight_decay Train_epochs  \
# 0            1  ...               16          0.10          0.06            3
# 1            2  ...               16          0.10          0.08            5
# 2            2  ...               16          0.10          0.03            3
# 3            1  ...               16          0.10          0.06            3
# 4            2  ...               16          0.05          0.05            5
# 5            2  ...               16          0.15          0.05            5
# 6            2  ...                8          0.10          0.01            3
# 7            1  ...               16          0.15          0.10            3
# 8            0  ...                8          0.10          0.01            3
# 9            0  ...               16          0.15          0.01            3
# 10           0  ...                8          0.10          0.10            3
# 11           1  ...                8          0.05          0.03            5
# 12           0  ...                8          0.10          0.10            3
# 13           0  ...                8          0.15          0.10            3
# 14           0  ...                8          0.10          0.01            5
# 15           1  ...                8          0.15          0.05            3
# 16           0  ...               16          0.10          0.06            3
# 17           1  ...               16          0.15          0.10            5
# 18           1  ...               16          0.05          0.08            5
# 19           0  ...                8          0.10          0.05            5
# 20           1  ...               16          0.10          0.06            3
# 21           1  ...               16          0.10          0.06            3
# 22           1  ...               16          0.10          0.06            3
# 23           2  ...                8          0.10          0.06            3
# 24           2  ...                8          0.10          0.01            3
# 25           0  ...                8          0.10          0.01            3
# 26           0  ...                8          0.10          0.01            5
# 27           0  ...               16          0.10          0.06            3
# 28           0  ...                8          0.15          0.04            5
# 29           1  ...               16          0.15          0.04            5
# 30           0  ...               16          0.10          0.08            3
# 31           1  ...               16          0.05          0.08            5
# 32           1  ...               16          0.15          0.05            5
# 33           0  ...                8          0.10          0.04            3
# 34           0  ...                8          0.10          0.04            3
# 35           1  ...                8          0.10          0.04            3
# 36           1  ...               16          0.10          0.08            5
# 37           2  ...               16          0.10          0.08            5
#
#     Train_loss  Validation_loss  Accuracy  Precision    Recall        F1
# 0       0.3350         0.712672  0.806400   0.797600  0.806400  0.799000
# 1       0.1750         0.723186  0.371800   0.569600  0.771500  0.655400
# 2       0.3037         0.591004  0.482000   0.487800  0.718600  0.581100
# 3       0.0484         1.038330  0.677400   0.644400  0.822200  0.722500
# 4       0.6940         0.693119  0.457400   0.587300  0.596800  0.592000
# 5       0.1946         0.687210  0.607800   0.577500  0.806600  0.673100
# 6       0.1248         0.528552  0.706000   0.689300  0.706000  0.689200
# 7       0.3633         1.821438  0.326000   0.324353  0.326000  0.322951
# 8       0.2607         0.764862  0.833200   0.830273  0.833200  0.831446
# 9       0.2118         1.757390  0.473054   0.467698  0.373054  0.450267
# 10      0.3706         1.866220  0.525589   0.532468  0.525589  0.527595
# 11      0.2349         1.362241  0.515957   0.515957  0.515957  0.526051
# 12      0.3202         2.079605  0.462982   0.594398  0.464298  0.439565
# 13      0.6958         0.697903  0.334000   0.111556  0.334000  0.167250
# 14      0.1568         2.792714  0.505528   0.593372  0.505528  0.487549
# 15      0.6966         0.693234  0.500000   0.250000  0.500000  0.333000
# 16      0.1614         0.785704  0.857600   0.853700  0.857600  0.855000
# 17      0.0760         2.472791  0.628916   0.674077  0.628916  0.603180
# 18      0.5500         2.665974  0.620293   0.648033  0.620293  0.601631
# 19      0.0479         0.847705  0.857200   0.818620  0.923000  0.866300
# 20      0.1208         4.385654  0.308000   0.553693  0.308000  0.319184
# 21      0.5947         0.956805  0.603015   0.605238  0.603015  0.603789
# 22      0.2232         0.697654  0.578200   0.551400  0.934200  0.693500
# 23      0.2614         0.664152  0.580200   0.558500  0.770700  0.647600
# 24      0.2739         0.678170  0.471600   0.480200  0.691600  0.566900
# 25      0.4529         1.817478  0.429630   0.454246  0.429630  0.396105
# 26      0.0158         4.261450  0.468677   0.515640  0.468677  0.452594
# 27      0.3482         0.869434  0.697400   0.690300  0.697400  0.691400
# 28      0.2002         1.984396  0.594598   0.597681  0.594598  0.590338
# 29      0.0912         2.378660  0.787000   0.800800  0.776000  0.788200
# 30      0.3524         1.304233  0.582000   0.610836  0.582000  0.590206
# 31      0.1321         1.986010  0.569409   0.579137  0.569409  0.553134
# 32      0.1273         1.848141  0.566111   0.576480  0.566111  0.550889
# 33      0.4901         1.345040  0.509000   0.559031  0.509000  0.528075
# 34      0.5272         0.718375  0.398600   0.464800  0.398600  0.357100
# 35      0.4688         0.776787  0.414600   0.505400  0.414600  0.390100
# 36      0.2096         0.953128  0.452600   0.541700  0.452600  0.446300
# 37      0.1717         0.683415  0.379400   0.295200  0.379400  0.301900
#
# [38 rows x 32 columns]

# %%
# Checking the unique values in the relevant columns
print(df['pretrained_model'].unique())
print(df['Labels'].unique())
print(df['Dataset'].unique())
print(df['Multiple'].unique())
print(df['Train_epochs'].unique())
print(df['warmup_ratio'].unique())
print(df['train_batchsize'].unique())
print(df['weight_decay'].unique())
# Out:
# ['deberta_v3' 'roberta_base' 'bert_base']
# [3 2]
# ['B4' 'B1' 'SNLI' 'VC' 'FEVERNLI' 'B2' 'ANLI' 'B3']
# [1 0]
# [3 5]
# [0.1  0.05 0.15]
# [16  8]
# [0.06 0.08 0.03 0.05 0.01 0.1  0.04]

# %% [markdown]
# Overview of frequencies per variable

# %%
labels_counts = df['Labels'].value_counts()
dataset_counts = df['Dataset'].value_counts()
multiple_counts = df['Multiple'].value_counts()
train_epochs_counts = df['Train_epochs'].value_counts()
pretrained_model_counts = df['pretrained_model'].value_counts()
weight_decay_counts = df['weight_decay'].value_counts()
warmup_ratio_counts = df['warmup_ratio'].value_counts()
train_batchsize_counts = df['train_batchsize'].value_counts()

# Frequency of characteristics
print("\nFrequency of characteristics in 'Labels':")
print(labels_counts)

print("\nFrequency of characteristics in 'Dataset':")
print(dataset_counts)

print("\nFrequency of characteristics in 'Multiple':")
print(multiple_counts)

print("\nFrequency of characteristics in 'Train_epochs':")
print(train_epochs_counts)

print("\nFrequency of characteristics in 'pretrained_model':")
print(pretrained_model_counts)

print("\nFrequency of characteristics in 'weight_decay':")
print(weight_decay_counts)

print("\nFrequency of characteristics in 'warmup_ratio':")
print(warmup_ratio_counts)

print("\nFrequency of characteristics in 'train_batchsize':")
print(train_batchsize_counts)
# Out:
# Frequency of characteristics in 'Labels':
# Labels
# 2    20
# 3    18
# Name: count, dtype: int64
#
# Frequency of characteristics in 'Dataset':
# Dataset
# B1          9
# B2          6
# VC          4
# SNLI        4
# ANLI        4
# FEVERNLI    4
# B3          4
# B4          3
# Name: count, dtype: int64
#
# Frequency of characteristics in 'Multiple':
# Multiple
# 1    22
# 0    16
# Name: count, dtype: int64
#
# Frequency of characteristics in 'Train_epochs':
# Train_epochs
# 3    23
# 5    15
# Name: count, dtype: int64
#
# Frequency of characteristics in 'pretrained_model':
# pretrained_model
# roberta_base    15
# bert_base       12
# deberta_v3      11
# Name: count, dtype: int64
#
# Frequency of characteristics in 'weight_decay':
# weight_decay
# 0.06    8
# 0.01    7
# 0.08    6
# 0.10    5
# 0.05    5
# 0.04    5
# 0.03    2
# Name: count, dtype: int64
#
# Frequency of characteristics in 'warmup_ratio':
# warmup_ratio
# 0.10    25
# 0.15     9
# 0.05     4
# Name: count, dtype: int64
#
# Frequency of characteristics in 'train_batchsize':
# train_batchsize
# 16    21
# 8     17
# Name: count, dtype: int64

# %% [markdown]
# # ANOVA
# In this step, an ANOVA is performed to analyse whether the selected parameters have a significant mean difference in terms of model accuracy.

# %%
model = ols('Accuracy ~ C(Labels) + C(Dataset) + C(Train_epochs) + C(train_batchsize) + C(pretrained_model) + C(train_batchsize)+ C(Multiple)+ C(weight_decay)+ C(warmup_ratio)', data=df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)

print(anova_table)
# Out:
#                        sum_sq    df          F    PR(>F)
# C(Labels)            0.010482   1.0   1.503533  0.236843
# C(Dataset)           0.131861   7.0   2.702127  0.044556
# C(Train_epochs)      0.001715   1.0   0.246060  0.626215
# C(train_batchsize)   0.000101   1.0   0.014454  0.905714
# C(pretrained_model)  0.221364   2.0  15.876871  0.000129
# C(Multiple)          0.043199   1.0   6.196673  0.023455
# C(weight_decay)      0.104432   6.0   2.496731  0.064337
# C(warmup_ratio)      0.004982   2.0   0.357340  0.704665
# Residual             0.118512  17.0        NaN       NaN

# %% [markdown]
# # Tukey HSD
# A Turkey HSD test is then carried out for the three factors that showed a significant mean difference in the ANOVA.

# %%
# Tukey's HSD Test für den Faktor 'Dataset'
tukey_dataset = pairwise_tukeyhsd(endog=df['Accuracy'], groups=df['Dataset'], alpha=0.05)
print("\nTukey's HSD Test 'Dataset':")
print(tukey_dataset)

# Tukey's HSD Test für den Faktor 'Mixed'
tukey_Mixed = pairwise_tukeyhsd(endog=df['Accuracy'], groups=df['Multiple'], alpha=0.05)
print("\nTukey's HSD Test 'Mixed':")
print(tukey_Mixed)

# Tukey's HSD Test für den Faktor 'Pretrained_model'
tukey_pretrained_model = pairwise_tukeyhsd(endog=df['Accuracy'], groups=df['pretrained_model'], alpha=0.05)
print("\nTukey's HSD Test 'Pretrained_model':")
print(tukey_pretrained_model)
# Out:
# Tukey's HSD Test 'Dataset':
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
#  group1   group2  meandiff p-adj   lower  upper  reject
# -------------------------------------------------------
#     ANLI       B1  -0.1198 0.8766 -0.4111 0.1714  False
#     ANLI       B2  -0.1727 0.6276 -0.4855 0.1402  False
#     ANLI       B3  -0.0481 0.9998 -0.3909 0.2946  False
#     ANLI       B4  -0.0217    1.0 -0.3919 0.3485  False
#     ANLI FEVERNLI  -0.1839 0.6586 -0.5267 0.1588  False
#     ANLI     SNLI  -0.1416 0.8742 -0.4843 0.2011  False
#     ANLI       VC  -0.1309 0.9121 -0.4736 0.2118  False
#       B1       B2  -0.0528 0.9971 -0.3083 0.2026  False
#       B1       B3   0.0717 0.9918 -0.2196 0.3629  False
#       B1       B4   0.0981 0.9727  -0.225 0.4213  False
#       B1 FEVERNLI  -0.0641 0.9958 -0.3554 0.2271  False
#       B1     SNLI  -0.0218    1.0 -0.3131 0.2695  False
#       B1       VC  -0.0111    1.0 -0.3023 0.2802  False
#       B2       B3   0.1245 0.8937 -0.1884 0.4374  False
#       B2       B4    0.151 0.8347 -0.1918 0.4937  False
#       B2 FEVERNLI  -0.0113    1.0 -0.3241 0.3016  False
#       B2     SNLI   0.0311    1.0 -0.2818 0.3439  False
#       B2       VC   0.0418 0.9998 -0.2711 0.3546  False
#       B3       B4   0.0264    1.0 -0.3437 0.3966  False
#       B3 FEVERNLI  -0.1358 0.8958 -0.4785 0.2069  False
#       B3     SNLI  -0.0935  0.985 -0.4362 0.2493  False
#       B3       VC  -0.0827 0.9927 -0.4255   0.26  False
#       B4 FEVERNLI  -0.1622 0.8382 -0.5324  0.208  False
#       B4     SNLI  -0.1199 0.9614 -0.4901 0.2503  False
#       B4       VC  -0.1092 0.9767 -0.4794  0.261  False
# FEVERNLI     SNLI   0.0423 0.9999 -0.3004 0.3851  False
# FEVERNLI       VC    0.053 0.9996 -0.2897 0.3958  False
#     SNLI       VC   0.0107    1.0  -0.332 0.3535  False
# -------------------------------------------------------
#
# Tukey's HSD Test 'Mixed':
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#      0      1   0.0063 0.8988 -0.0933 0.1059  False
# ---------------------------------------------------
#
# Tukey's HSD Test 'Pretrained_model':
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==============================================================
#   group1      group2    meandiff p-adj   lower   upper  reject
# --------------------------------------------------------------
#  bert_base   deberta_v3   0.1256 0.0377  0.0061  0.2451   True
#  bert_base roberta_base  -0.1009 0.0807 -0.2118    0.01  False
# deberta_v3 roberta_base  -0.2265 0.0001 -0.3402 -0.1128   True
# --------------------------------------------------------------
